# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data loading
df = pd.read_csv('EDA_graph.csv')

print(df.head())

print(df.describe())

print(df.isnull().sum())
# Out:
#    person_age person_home_ownership  person_emp_length loan_intent loan_grade  \
# 0          21                   OWN                  5   EDUCATION          B
# 1          25              MORTGAGE                  1     MEDICAL          C
# 2          23                  RENT                  4     MEDICAL          C
# 3          24                  RENT                  8     MEDICAL          C
# 4          21                   OWN                  2     VENTURE          A
#
#    loan_int_rate  loan_status  loan_percent_income  cb_perso0_default_o0_file  \
# 0         0.1114            0                 0.10                          0
# 1         0.1287            1                 0.57                          0
# 2         0.1523            1                 0.53                          0
# 3         0.1427            1                 0.55                          1
# 4         0.0714            1                 0.25                          0
#
#    cb_person_cred_hist_length  log_person_income  log_loan_amnt
# 0                           2           9.169623       6.908755
# 1                           3           9.169623       8.612685
# 2                           2          11.089821      10.463132
# 3                           4          10.904138      10.463132
# 4                           2           9.200391       7.824446
#          person_age  person_emp_length  loan_int_rate   loan_status  \
# count  32564.000000       32564.000000   32564.000000  32564.000000
# mean      27.710294           4.760349       0.110099      0.218247
# std        6.178842           3.980674       0.030817      0.413062
# min       20.000000           0.000000       0.054200      0.000000
# 25%       23.000000           2.000000       0.084900      0.000000
# 50%       26.000000           4.000000       0.109900      0.000000
# 75%       30.000000           7.000000       0.131100      0.000000
# max       80.000000          41.000000       0.232200      1.000000
#
#        loan_percent_income  cb_perso0_default_o0_file  \
# count         32564.000000               32564.000000
# mean              0.170241                   0.176360
# std               0.106738                   0.381132
# min               0.000000                   0.000000
# 25%               0.090000                   0.000000
# 50%               0.150000                   0.000000
# 75%               0.230000                   0.000000
# max               0.830000                   1.000000
#
#        cb_person_cred_hist_length  log_person_income  log_loan_amnt
# count                 32564.00000       32564.000000   32564.000000
# mean                      5.80024          10.924148       8.941497
# std                       4.04681           0.563156       0.711544
# min                       2.00000           8.294300       6.216606
# 25%                       3.00000          10.558439       8.517393
# 50%                       4.00000          10.915107       8.987322
# 75%                       8.00000          11.279744       9.409273
# max                      30.00000          13.762111      10.463132
# person_age                    0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_perso0_default_o0_file     0
# cb_person_cred_hist_length    0
# log_person_income             0
# log_loan_amnt                 0
# dtype: int64

# %%
# Numerical variables summary
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(15, 12))
for i, col in enumerate(numeric_cols):
    plt.subplot(4, 3, i+1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Categorical variables summary
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_cols):
    plt.subplot(1, len(categorical_cols), i+1)
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# correlation heatmap
plt.figure(figsize=(12, 8))
corr = df.select_dtypes(include=['int64', 'float64']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
# loan_status
if 'loan_status' in df.columns:
    status_counts = df['loan_status'].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Loan Status Distribution')
    plt.show()
    
    print("Loan Status Counts:")
    print(status_counts)
    print("\nLoan Status Percentages:")
    print((status_counts/len(df)*100).round(1))
# Out:
# Loan Status Counts:
# loan_status
# 0    25457
# 1     7107
# Name: count, dtype: int64
#
# Loan Status Percentages:
# loan_status
# 0    78.2
# 1    21.8
# Name: count, dtype: float64

# %%
# cb_person_default_on_file
if 'cb_person_default_on_file' in df.columns:
    status_counts = df['cb_person_default_on_file'].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Historical default Distribution')
    plt.show()
    

    print("Historical default Counts:")
    print(status_counts)
    print("\nHistorical default Percentages:")
    print((status_counts/len(df)*100).round(1))

# %%
if 'person_home_ownership' in df.columns:
    status_counts = df['person_home_ownership'].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('person_home_ownership Distribution')
    plt.show()
    

    print("person_home_ownership Counts:")
    print(status_counts)
    print("\nperson_home_ownership Percentages:")
    print((status_counts/len(df)*100).round(1))
# Out:
# person_home_ownership Counts:
# person_home_ownership
# RENT        16439
# MORTGAGE    13435
# OWN          2583
# OTHER         107
# Name: count, dtype: int64
#
# person_home_ownership Percentages:
# person_home_ownership
# RENT        50.5
# MORTGAGE    41.3
# OWN          7.9
# OTHER        0.3
# Name: count, dtype: float64

# %%
if 'loan_grade' in df.columns:
    status_counts = df['loan_grade'].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('loan_grade Distribution')
    plt.show()
    

    print("loan_grade Counts:")
    print(status_counts)
    print("\loan_grade Percentages:")
    print((status_counts/len(df)*100).round(1))
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\super\AppData\Local\Temp\ipykernel_34444\3922348244.py:11: SyntaxWarning: invalid escape sequence '\l'
#   print("\loan_grade Percentages:")
# loan_grade Counts:
# loan_grade
# A    10769
# B    10448
# C     6453
# D     3625
# E      964
# F      241
# G       64
# Name: count, dtype: int64
# \loan_grade Percentages:
# loan_grade
# A    33.1
# B    32.1
# C    19.8
# D    11.1
# E     3.0
# F     0.7
# G     0.2
# Name: count, dtype: float64

# %%
if 'loan_intent' in df.columns:
    status_counts = df['loan_intent'].value_counts()
    plt.figure(figsize=(8, 6))
    plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('loan_intent Distribution')
    plt.show()
    

    print("loan_intent Counts:")
    print(status_counts)
    print("\loan_intent Percentages:")
    print((status_counts/len(df)*100).round(1))
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# <>:11: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\super\AppData\Local\Temp\ipykernel_34444\3604058109.py:11: SyntaxWarning: invalid escape sequence '\l'
#   print("\loan_intent Percentages:")
# loan_intent Counts:
# loan_intent
# EDUCATION            6450
# MEDICAL              6068
# VENTURE              5713
# PERSONAL             5517
# DEBTCONSOLIDATION    5211
# HOMEIMPROVEMENT      3605
# Name: count, dtype: int64
# \loan_intent Percentages:
# loan_intent
# EDUCATION            19.8
# MEDICAL              18.6
# VENTURE              17.5
# PERSONAL             16.9
# DEBTCONSOLIDATION    16.0
# HOMEIMPROVEMENT      11.1
# Name: count, dtype: float64
